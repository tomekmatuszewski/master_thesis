# %%
# %%sql
# SELECT * FROM silver.dim_awards
# Out:
# 25/04/22 20:34:26 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# +----+-----------------------+------------------------------+-------------------------------------------------------------+---------+
# | SK |                Player |                        Award |                                                       Stats |  season |
# +----+-----------------------+------------------------------+-------------------------------------------------------------+---------+
# |  0 |            Tim Duncan |                          MVP |       FG%: .513, PPG: 23.3, RPG: 12.9, BLKPG: 2.9, APG: 3.9 | 2002_03 |
# |  1 |           Ben Wallace | Defensive Player of the Year |        FG%: .481, PPG: 6.9, RPG: 15.4, BLKPG: 3.2, APG: 1.6 | 2002_03 |
# |  2 |     Amar'e Stoudemire |           Rookie of the Year |        FG%: .472, PPG: 13.5, RPG: 8.8, BLKPG: 1.1, APG: 1.0 | 2002_03 |
# ...

# %%
# %%sql
# SELECT * FROM bronze.awards
# Out:
# +------------------------------------------+------------------------------+-----------------------------------------------------------+--------+
# |                                    AWARD |                    RECIPIENT |                                                     STATS | season |
# +------------------------------------------+------------------------------+-----------------------------------------------------------+--------+
# |                                      MVP |              Steve Nash, PHX |     FG%: .502, PPG: 15.5, RPG: 3.3, BLKPG: 0.1, APG: 11.5 |   2005 |
# |             Defensive Player of the Year |             Ben Wallace, DET |      FG%: .453, PPG: 9.7, RPG: 12.2, BLKPG: 2.4, APG: 1.7 |   2005 |
# |                       Rookie of the Year |            Emeka Okafor, CHA |     FG%: .447, PPG: 15.1, RPG: 10.9, BLKPG: 1.7, APG: 0.9 |   2005 |
# ...

# %%
# %%sql
# SELECT * FROM silver.dim_salary where Player = 'Joel Embiid'
# Out:
# +------+-------------+--------------------+----------+--------------+------------+----------------+
# |   SK |      Player |               team |   salary | start_season | end_season | current_season |
# +------+-------------+--------------------+----------+--------------+------------+----------------+
# | 5220 | Joel Embiid | Philadelphia 76ers |  4427640 |      2014_15 |    2014_15 |        2024_25 |
# | 5221 | Joel Embiid | Philadelphia 76ers |  4626960 |      2015_16 |    2015_16 |        2024_25 |
# | 5222 | Joel Embiid | Philadelphia 76ers |  4826160 |      2016_17 |    2016_17 |        2024_25 |
# | 5223 | Joel Embiid | Philadelphia 76ers | 25250000 |      2017_18 |    2017_18 |        2024_25 |
# | 5224 | Joel Embiid | Philadelphia 76ers | 25467250 |      2018_19 |    2018_19 |        2024_25 |
# | 5225 | Joel Embiid | Philadelphia 76ers | 27504630 |      2019_20 |    2019_20 |        2024_25 |
# ...

# %%
# %%sql
# SELECT * FROM silver.stats where PlayerName = 'Joel Embiid' order by season desc
# Out:
# +------------+-------------+--------+----------+----------------------------+----------+---------------------------------------------------------+-----+----+------+------+------+------+------+-----+-----+------+------+------+------+------+-----+-----+-----+-----+-----+-----+---------+--------------+
# |    SKStats |  PlayerName | SKTeam | SKSalary |                   SKAwards | SKSeason |                                              SKInjuries | POS | GP |  MIN |  PTS |  FGM |  FGA |  FG% | 3PM | 3PA |  3P% |  FTM |  FTA |  FT% |  REB | AST | STL | BLK |  TO | DD2 | TD3 |  season | season_phase |
# +------------+-------------+--------+----------+----------------------------+----------+---------------------------------------------------------+-----+----+------+------+------+------+------+-----+-----+------+------+------+------+------+-----+-----+-----+-----+-----+-----+---------+--------------+
# ...
